# %%
import pandas as pd
from pathlib import Path
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
spotify_2023 = pd.read_csv("Resources/spotify_2023.csv", encoding='ISO-8859-1')

spotify_2023.head(10)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %%
spotify_2023 = spotify_2023.dropna()

# %%
for index, row in spotify_2023.iterrows():
    if row['streams'] >= 100000000:
        spotify_2023.at[index, 'hit_song'] = "Hit"
    else:
        spotify_2023.at[index, 'hit_song'] = "Not Hit"

# %%
spotify_2023.head(10)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %%
spotify_2023.tail(10)
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 943         Privileged Rappers    Drake, 21 Savage             2
# 944              The Astronaut                 Jin             1
# 945            BackOutsideBoyz               Drake             1
# 946                 Broke Boys    Drake, 21 Savage             2
# 947              The Great War        Taylor Swift             1
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 943           2022              11             4                  1007
# 944           2022              10            28                   481
# ...

# %%
y =spotify_2023['hit_song']
X =spotify_2023.drop(columns='hit_song')

# %%
X.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts      streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
y[:5]
# Out:
# 0    Hit
# 1    Hit
# 2    Hit
# 3    Hit
# 4    Hit
# Name: hit_song, dtype: object

# %%
X = pd.get_dummies(X)

# %%
X.head()
# Out:
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# 4             1           2023               5            18
#
#    in_spotify_playlists  in_spotify_charts      streams  in_apple_playlists  \
# 0                   553                147  141381703.0                  43
# 1                  1474                 48  133716286.0                  48
# 2                  1397                113  140003974.0                  94
# 3                  7858                100  800840817.0                 116
# 4                  3133                 50  303236322.0                  84
#
#    in_apple_charts  in_deezer_charts  ...  key_C#  key_D  key_D#  key_E  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.shape
# Out:
# (612, 1890)

# %%
X_test.shape
# Out:
# (204, 1890)

# %%
scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = model.predict(X_test_scaled)


y_pred
# Out:
# array(['Hit', 'Not Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit',
#        'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit',
#        'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit',
#        'Hit', 'Hit', 'Hit', 'Not Hit', 'Hit', 'Not Hit', 'Hit', 'Hit',
#        'Hit', 'Not Hit', 'Hit', 'Not Hit', 'Hit', 'Hit', 'Hit', 'Hit',
#        'Hit', 'Hit', 'Hit', 'Hit', 'Not Hit', 'Hit', 'Hit', 'Hit', 'Hit',
#        'Hit', 'Not Hit', 'Not Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit',
#        'Hit', 'Not Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit',
#        'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Not Hit',
#        'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit',
#        'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit',
#        'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Not Hit', 'Hit', 'Hit',
#        'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Hit', 'Not Hit', 'Hit', 'Hit',
# ...

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[154,  20],
#        [ 18,  12]], dtype=int64)

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          Hit       0.90      0.89      0.89       174
#      Not Hit       0.38      0.40      0.39        30
#
#     accuracy                           0.81       204
#    macro avg       0.64      0.64      0.64       204
# weighted avg       0.82      0.81      0.82       204
